# %%
import pandas as pd
from faker import Faker

# %%
ruta_clientes = r"C:\Users\renzo\OneDrive\Escritorio\BD_Aurelion\Clientes.csv"
ruta_Detalle_ventas = r"C:\Users\renzo\OneDrive\Escritorio\BD_Aurelion\Detalle_Ventas.csv"
ruta_Productos = r"C:\Users\renzo\OneDrive\Escritorio\BD_Aurelion\Productos.csv"
ruta_Ventas = r"C:\Users\renzo\OneDrive\Escritorio\BD_Aurelion\Ventas.csv"

# %%
df_clientes = pd.read_csv(ruta_clientes)
df_detalle_ventas = pd.read_csv(ruta_Detalle_ventas)
df_productos = pd.read_csv(ruta_Productos)
df_ventas = pd.read_csv(ruta_Ventas)

# %%
df_ventas
# Out:
#        id_venta  id_cliente                fecha  \
# 0             1         365  2023-01-03 14:00:00
# 1             2         327  2023-01-04 05:00:00
# 2             3         462  2023-01-05 07:00:00
# 3             4         534  2023-01-06 12:00:00
# 4             5         365  2023-01-06 18:59:00
# ...         ...         ...                  ...
# 19079     19080         265  2024-10-31 19:40:00
# 19080     19081         325  2024-10-31 20:09:00
# 19081     19082         175  2024-10-31 21:56:00
# 19082     19083         552  2024-10-31 22:16:00
# 19083     19084          76  2024-10-31 22:28:00
#
#                                   nombre_cliente  \
# 0                                 Emma Gutierrez
# 1                                   Julieta Sosa
# 2                                  Delfina Ramos
# 3      Francisco Valentina Jazmin Chavez Vazquez
# 4                                 Emma Gutierrez
# ...                                          ...
# ...

# %%
df_detalle_ventas
# Out:
#        id_detalle  id_venta  id_producto           nombre_producto  cantidad  \
# 0               1         2           71               Vodka 700ml         4
# 1               2         3           52  Detergente Líquido 750ml         2
# 2               3         3           27            Alfajor Simple         2
# 3               4         3           23         Bizcochos Salados         1
# 4               5         4           11          Café Molido 250g         1
# ...           ...       ...          ...                       ...       ...
# 34770       34771     19081           14           Leche Entera 1L         2
# 34771       34772     19082           33  Chocolate con Leche 100g         3
# 34772       34773     19083           21       Pan Lactal Integral         4
# 34773       34774     19084           85     Jugo en Polvo Naranja         3
# 34774       34775     19084           11          Café Molido 250g         3
#
#        precio_unitario  importe
# ...
